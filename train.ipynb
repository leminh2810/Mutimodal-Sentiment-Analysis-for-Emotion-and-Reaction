# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/multimodal-emotion-recognition
# Out:
# /content/multimodal-emotion-recognition

# %%
# !pip install -r requirements.txt
# !pip install facenet-pytorch
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 114.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 98.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 94.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 18.2 MB/s eta 0:00:00
# ...

# %%
# %cd ravdess_preprocessing
# !python extract_faces.py
# Out:
# /content/multimodal-emotion-recognition/ravdess_preprocessing

# %%
# !pip install --upgrade librosa
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...

# %%
# !python extract_audios.py
# Out:
# Traceback (most recent call last):
#   File "/content/multimodal-emotion-recognition/ravdess_preprocessing/extract_audios.py", line 14, in <module>
#     for actor in os.listdir(root):
#                  ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/lustre/scratch/chumache/RAVDESS_or/'

# %%
# !python create_annotations.py
# Out:
# Traceback (most recent call last):
#   File "/content/multimodal-emotion-recognition/ravdess_preprocessing/create_annotations.py", line 15, in <module>
#     for i,actor in enumerate(os.listdir(root)):
#                              ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/lustre/scratch/chumache/RAVDESS_or/'

# %%
# !cp -r /content/multimodal-emotion-recognition /content/drive/MyDrive
# Out:
# ^C

# %%
# %cd /content/drive/MyDrive/multimodal-emotion-recognition
# Out:
# /content/drive/MyDrive/multimodal-emotion-recognition

# %%
# !ls
# Out:
# dataset.py				     main.py	 __pycache__		train.py
# datasets				     model.py	 ravdess_preprocessing	transforms.py
# EfficientFace_Trained_on_AffectNet7.pth.tar  models	 README.md		utils.py
# emotionfigure.png			     models.rar  requirements.txt	validation.py
# LICENSE					     opts.py	 results

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [31][120/480]	 lr: 0.04000	Time 0.839 (0.920)	Data 0.154 (0.224)	Loss 0.0139 (0.0414)	Prec@1 100.00000 (99.35433)	Prec@5 100.00000 (99.99999)
# Epoch: [31][130/480]	 lr: 0.04000	Time 0.883 (0.914)	Data 0.180 (0.219)	Loss 0.0095 (0.0403)	Prec@1 100.00000 (99.37977)	Prec@5 100.00000 (100.00000)
# Epoch: [31][140/480]	 lr: 0.04000	Time 0.864 (0.909)	Data 0.157 (0.214)	Loss 0.0128 (0.0394)	Prec@1 100.00000 (99.42376)	Prec@5 100.00000 (100.00000)
# Epoch: [31][150/480]	 lr: 0.04000	Time 0.728 (0.902)	Data 0.130 (0.210)	Loss 0.0617 (0.0398)	Prec@1 100.00000 (99.37914)	Prec@5 100.00000 (100.00000)
# Epoch: [31][160/480]	 lr: 0.04000	Time 0.783 (0.897)	Data 0.129 (0.207)	Loss 0.0141 (0.0387)	Prec@1 100.00000 (99.41770)	Prec@5 100.00000 (100.00000)
# Epoch: [31][170/480]	 lr: 0.04000	Time 0.867 (0.892)	Data 0.136 (0.204)	Loss 0.0189 (0.0386)	Prec@1 100.00000 (99.45175)	Prec@5 100.00000 (100.00000)
# ...

# %%
# !python main.py  --no_train --no_val --result_path /content/drive/MyDrive/multimodal-emotion-recognition/results
# Out:
# Namespace(annotation_path='ravdess_preprocessing/annotations.txt', result_path='/content/drive/MyDrive/multimodal-emotion-recognition/results', store_name='RAVDESS_multimodalcnn_15', dataset='RAVDESS', n_classes=8, model='multimodalcnn', num_heads=1, device='cuda', sample_size=224, sample_duration=15, learning_rate=0.04, momentum=0.9, lr_steps=[40, 55, 65, 70, 200, 250], dampening=0.9, weight_decay=0.001, lr_patience=10, batch_size=8, n_epochs=100, begin_epoch=1, resume_path='', pretrain_path='EfficientFace_Trained_on_AffectNet7.pth.tar', no_train=True, no_val=True, test=True, test_subset='test', n_threads=16, video_norm_value=255, manual_seed=1, fusion='ia', mask='softhard', arch='multimodalcnn')
# Initializing efficientnet
# Total number of trainable parameters:  1854766
# ...
